# %% [markdown]
# # Capstone Project Report - Clustering Toronto and Vancouver Neighborhoods

# %% [markdown]
# ## I. Introduction & Business Problem

# %% [markdown]
# When an individual lives in a diverse and physically large country like Canada, one is bound to move from one city to another. Either at the personal level as one searches/move for jobs or at the business level where a restaurant might be interested in opening a branch in another city. These individuals or entities would be interested in neighborhoods that are similar to each other between the two cities.
#
# **Business Problem:** How can we find a similar neighborhood in another city from our own?
#
# **Target Audience:** Anyone interested in moving between cities including businesses interested in a strategy to identify new location across countries.

# %% [markdown]
# ## II. Data

# %% [markdown]
# To address this business problem and create a proof of concept solution, we will be interested in Toronto Neighborhoods and their similar neighborhoods in Vancouver. Geographically, they are quite far apart where Toronto can be considered to be on the East Coast of continental North America and Vancouver is on the West Coast.
#
# **List of Neighborhoods:** Similar to the Toronto Lab, we will be obtaining a complete list of neighborhoods for the the two cities using first **Wikipedia**.
#
# **Geo Location:** Using the geopy library, we would be able to join the list of neighborhoods to their respective cordinates.
#
# **Foursquare API:** Then using the Foursquare API will we be able to obtain the characteristics and data on each neighborhood. Then the data will be joined with the list of neighborhood. This final dataset will be used for K-means clustering of neighborhoods to find clusters--groups of similar neighborhoods.

# %% [markdown]
# ## III. Methodology

# %% [markdown]
# In order to deliver on the business goal at hand of finding similar neighborhoods in a pool of Vancouver and Toronto Neighborhoods, the following was completed:
#
# 1. Getting a list of Neighborhoods from **Wikipedia**. A combination of **BeautifulSoup** and manual implementation was used to retrieve a list of Postal codes of the respective cities. Then using the **Google Maps API**, the postal code and province of where it came from was used to search for Geocoordinates.
#
# 2. After getting the coordinates for each postal code, the **Foursquare API** was used to retrieve a list of venues most popular in the neighborhood. Then, characteristics dummy variables were generated for each.
#
# 3. **K-Means Clustering** (k=10) was used to identify similar neighborhoods.

# %% [markdown]
# ## IV. Results

# %% [markdown]
# In general, the results showed well clustered groups with a few exceptions where groups are only one member with no other similar neighborhoods in it. This was unfortunate. Some good clusters deserving of attention below includes:
#
# * **Cluster 2:** Includes a lot of Falafel Restaurants that were part of the most common venues.
# * **Cluster 3:** Dominated by Zoos and parks in the top venues.
# * **Cluster 4:** Construction & Landscaping venues with Ethiopian Restaurants
# * **Cluster 5:** All of the neighborhood's top 10 venues matched exactly. They seem geographically close to each other too in Vancouver.
# * **Cluster 10:** Trails and Parks

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis

# %%
#cluster1
cluster1 = pd.read_csv("cluster1.csv")
cluster1
# Out:
#   PostalCode Province   search   Latitude   Longitude 1st Most Common Venue  \
# 0        V5E       BC  V5E, BC  49.231088 -122.947268     Other Repair Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Zoo    Falafel Restaurant     Electronics Store
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0  Ethiopian Restaurant           Event Space               Exhibit
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0           Fabric Shop                  Fair                   Farm

# %%
#cluster2
cluster2 = pd.read_csv("cluster2.csv")
cluster2
# Out:
#     PostalCode Province   search   Latitude   Longitude 1st Most Common Venue  \
# 0          M5A       ON  M5A, ON  43.654260  -79.360636           Coffee Shop
# 1          M1B       ON  M1B, ON  43.806686  -79.194353            Print Shop
# 2          M3B       ON  M3B, ON  43.745906  -79.352188   Japanese Restaurant
# 3          M5B       ON  M5B, ON  43.656081  -79.380171        Clothing Store
# 4          M6B       ON  M6B, ON  43.709577  -79.445073                   Pub
# ..         ...      ...      ...        ...         ...                   ...
# 145        V9E       BC  V9E, BC  48.527525 -123.461885                  Lake
# 146        V9R       BC  V9R, BC  49.165722 -124.000170                  Lake
# 147        V9V       BC  V9V, BC  49.237891 -124.032354          Home Service
# 148        V9W       BC  V9W, BC  50.014661 -125.260855         Tour Provider
# 149        V9Y       BC  V9Y, BC  49.285483 -124.865726            Campground
#
#           2nd Most Common Venue 3rd Most Common Venue  \
# 0                        Bakery                  Park
# 1          Fast Food Restaurant                   Zoo
# 2                          Café            Beer Store
# 3                   Coffee Shop    Italian Restaurant
# 4           Japanese Restaurant      Sushi Restaurant
# ..                          ...                   ...
# 145                         Zoo                  Farm
# 146  Construction & Landscaping          Tennis Court
# 147           Recreation Center                  Farm
# 148      Furniture / Home Store                   Zoo
# 149                       River             Drugstore
#
#            4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0                            Pub                  Café        Breakfast Spot
# 1             Falafel Restaurant     Electronics Store  Ethiopian Restaurant
# 2                     Restaurant           Coffee Shop                   Gym
# 3                Bubble Tea Shop            Restaurant                  Café
# 4                           Park                   Zoo                  Fair
# ..                           ...                   ...                   ...
# 145            Electronics Store  Ethiopian Restaurant           Event Space
# 146                   Campground    Falafel Restaurant     Electronics Store
# 147            Electronics Store  Ethiopian Restaurant           Event Space
# 148           Falafel Restaurant     Electronics Store  Ethiopian Restaurant
# 149  Eastern European Restaurant     Electronics Store  Ethiopian Restaurant
#
#     7th Most Common Venue 8th Most Common Venue      9th Most Common Venue  \
# 0                 Theater                  Bank                 Beer Store
# 1             Event Space               Exhibit                Fabric Shop
# 2        Asian Restaurant   Sporting Goods Shop       Caribbean Restaurant
# 3          Cosmetics Shop              Tea Room  Middle Eastern Restaurant
# 4       Electronics Store  Ethiopian Restaurant                Event Space
# ..                    ...                   ...                        ...
# 145               Exhibit           Fabric Shop                       Fair
# 146  Ethiopian Restaurant           Event Space                    Exhibit
# 147               Exhibit           Fabric Shop                       Fair
# 148           Event Space               Exhibit                Fabric Shop
# 149           Event Space               Exhibit                Fabric Shop
#
#     10th Most Common Venue
# 0        French Restaurant
# 1                     Fair
# 2       Chinese Restaurant
# 3                    Diner
# 4                  Exhibit
# ..                     ...
# 145     Falafel Restaurant
# 146            Fabric Shop
# 147     Falafel Restaurant
# 148                   Fair
# 149                   Fair
#
# [150 rows x 15 columns]

# %%
]
# Out:
# Empty DataFrame
# Columns: [PostalCode, Province, search, Latitude, Longitude, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
#cluster3
cluster3 = pd.read_csv("cluster3.csv")
cluster3
# Out:
#    PostalCode Province   search   Latitude   Longitude 1st Most Common Venue  \
# 0         M3A       ON  M3A, ON  43.753259  -79.329656     Food & Drink Shop
# 1         M6E       ON  M6E, ON  43.689026  -79.453512                  Park
# 2         M4J       ON  M4J, ON  43.685347  -79.338106                  Park
# 3         M4N       ON  M4N, ON  43.728020  -79.388790           Swim School
# 4         M9N       ON  M9N, ON  43.706876  -79.518188                  Park
# 5         M2P       ON  M2P, ON  43.752758  -79.400049                  Park
# 6         M9R       ON  M9R, ON  43.688905  -79.554724        Sandwich Place
# 7         M1V       ON  M1V, ON  43.815252  -79.284577            Playground
# 8         M4W       ON  M4W, ON  43.679563  -79.377529                  Park
# 9         M8X       ON  M8X, ON  43.653654  -79.506944                  Pool
# 10        V2X       BC  V2X, BC  49.222757 -122.617545                 Track
# 11        V3B       BC  V3B, BC  49.281582 -122.753588         Auto Workshop
# 12        V3T       BC  V3T, BC  49.192124 -122.856366                  Park
# 13        V4L       BC  V4L, BC  49.038245 -123.053574                Lawyer
# 14        V7M       BC  V7M, BC  49.321586 -123.081228                  Park
# 15        V8Y       BC  V8Y, BC  48.508104 -123.366692                  Park
# 16        V8Z       BC  V8Z, BC  48.486728 -123.397706          Home Service
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Park                   Zoo    Falafel Restaurant
# 1          Women's Store                  Pool                   Zoo
# 2          Metro Station     Convenience Store    Falafel Restaurant
# 3                   Park              Bus Line                   Zoo
# 4                    Zoo    Falafel Restaurant     Electronics Store
# 5      Convenience Store                  Bank                   Zoo
# 6      Mobile Phone Shop                  Park                   Zoo
# 7                   Park                   Zoo                  Fair
# 8             Playground                 Trail                   Zoo
# 9                   Park                 River                   Zoo
# 10                  Park                   Zoo             Drugstore
# 11            Playground                  Park    Falafel Restaurant
# 12        Clothing Store                   Zoo             Drugstore
# 13      Business Service                  Park                   Zoo
# 14                   Zoo    Falafel Restaurant     Electronics Store
# 15                   Zoo    Falafel Restaurant     Electronics Store
# 16                  Pool                  Park    Falafel Restaurant
#
#           5th Most Common Venue        6th Most Common Venue  \
# 0             Electronics Store         Ethiopian Restaurant
# 1                          Fair  Eastern European Restaurant
# 2             Electronics Store         Ethiopian Restaurant
# 3                          Fair            Electronics Store
# 4          Ethiopian Restaurant                  Event Space
# 5            Falafel Restaurant         Ethiopian Restaurant
# 6                          Fair            Electronics Store
# 7   Eastern European Restaurant            Electronics Store
# 8                          Fair  Eastern European Restaurant
# 9                          Fair  Eastern European Restaurant
# 10            Electronics Store         Ethiopian Restaurant
# 11  Eastern European Restaurant            Electronics Store
# 12            Electronics Store         Ethiopian Restaurant
# 13  Eastern European Restaurant         Ethiopian Restaurant
# 14         Ethiopian Restaurant                  Event Space
# 15         Ethiopian Restaurant                  Event Space
# 16            Electronics Store         Ethiopian Restaurant
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0            Event Space               Exhibit           Fabric Shop
# 1      Electronics Store  Ethiopian Restaurant           Event Space
# 2            Event Space               Exhibit           Fabric Shop
# 3   Ethiopian Restaurant           Event Space               Exhibit
# 4                Exhibit           Fabric Shop                  Fair
# 5            Event Space               Exhibit           Fabric Shop
# 6   Ethiopian Restaurant           Event Space               Exhibit
# 7   Ethiopian Restaurant           Event Space               Exhibit
# 8      Electronics Store  Ethiopian Restaurant           Event Space
# 9      Electronics Store  Ethiopian Restaurant           Event Space
# 10           Event Space               Exhibit           Fabric Shop
# 11  Ethiopian Restaurant           Event Space               Exhibit
# 12           Event Space               Exhibit           Fabric Shop
# 13           Event Space               Exhibit           Fabric Shop
# 14               Exhibit           Fabric Shop                  Fair
# 15               Exhibit           Fabric Shop                  Fair
# 16           Event Space               Exhibit           Fabric Shop
#
#    10th Most Common Venue
# 0                    Fair
# 1                 Exhibit
# 2                    Fair
# 3             Fabric Shop
# 4                    Farm
# 5                    Fair
# 6             Fabric Shop
# 7             Fabric Shop
# 8                 Exhibit
# 9                 Exhibit
# 10                   Fair
# 11            Fabric Shop
# 12                   Fair
# 13                   Fair
# 14                   Farm
# 15                   Farm
# 16                   Fair

# %%
#cluster4
cluster4 = pd.read_csv("cluster4.csv")
cluster4
# Out:
#   PostalCode Province   search   Latitude   Longitude  \
# 0        M1J       ON  M1J, ON  43.744734  -79.239476
# 1        M8Y       ON  M8Y, ON  43.636258  -79.498509
# 2        V2S       BC  V2S, BC  49.017244 -122.284334
# 3        V3A       BC  V3A, BC  49.083738 -122.645903
# 4        V9T       BC  V9T, BC  49.215850 -123.986978
#
#         1st Most Common Venue       2nd Most Common Venue  \
# 0  Construction & Landscaping                  Playground
# 1  Construction & Landscaping              Baseball Field
# 2                        Farm  Construction & Landscaping
# 3  Construction & Landscaping                         Zoo
# 4  Construction & Landscaping                         Zoo
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                   Zoo                  Farm     Electronics Store
# 1                   Zoo                  Farm  Ethiopian Restaurant
# 2                   Zoo     Electronics Store  Ethiopian Restaurant
# 3                  Farm     Electronics Store  Ethiopian Restaurant
# 4                  Farm     Electronics Store  Ethiopian Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0  Ethiopian Restaurant           Event Space               Exhibit
# 1           Event Space               Exhibit           Fabric Shop
# 2           Event Space               Exhibit           Fabric Shop
# 3           Event Space               Exhibit           Fabric Shop
# 4           Event Space               Exhibit           Fabric Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 0           Fabric Shop                   Fair
# 1                  Fair     Falafel Restaurant
# 2                  Fair     Falafel Restaurant
# 3                  Fair     Falafel Restaurant
# 4                  Fair     Falafel Restaurant

# %%
#cluster5
cluster5 = pd.read_csv("cluster5.csv")
cluster5
# Out:
#   PostalCode Province   search   Latitude   Longitude 1st Most Common Venue  \
# 0        V1S       BC  V1S, BC  50.623004 -120.410181      Business Service
# 1        V1V       BC  V1V, BC  49.950056 -119.428336      Business Service
# 2        V4X       BC  V4X, BC  49.088824 -122.415286      Business Service
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Zoo    Falafel Restaurant     Electronics Store
# 1                   Zoo    Falafel Restaurant     Electronics Store
# 2                   Zoo    Falafel Restaurant     Electronics Store
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0  Ethiopian Restaurant           Event Space               Exhibit
# 1  Ethiopian Restaurant           Event Space               Exhibit
# 2  Ethiopian Restaurant           Event Space               Exhibit
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0           Fabric Shop                  Fair                   Farm
# 1           Fabric Shop                  Fair                   Farm
# 2           Fabric Shop                  Fair                   Farm

# %%
#cluster6
cluster6 = pd.read_csv("cluster6.csv")
cluster6
# Out:
#   PostalCode Province   search  Latitude   Longitude 1st Most Common Venue  \
# 0        V9S       BC  V9S, BC  49.18839 -123.975037   Rental Car Location
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Zoo                  Farm     Electronics Store
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0  Ethiopian Restaurant           Event Space               Exhibit
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0           Fabric Shop                  Fair     Falafel Restaurant

# %%
#cluster7
cluster7 = pd.read_csv("cluster7.csv")
cluster7
# Out:
#   PostalCode Province   search   Latitude   Longitude 1st Most Common Venue  \
# 0        M9M       ON  M9M, ON  43.724766  -79.532242        Baseball Field
# 1        V9A       BC  V9A, BC  48.437369 -123.411284        Baseball Field
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Zoo                  Farm  Ethiopian Restaurant
# 1                   Zoo                  Farm  Ethiopian Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Event Space               Exhibit           Fabric Shop
# 1           Event Space               Exhibit           Fabric Shop
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                  Fair    Falafel Restaurant         Farmers Market
# 1                  Fair    Falafel Restaurant         Farmers Market

# %%
#cluster8
cluster8 = pd.read_csv("cluster8.csv")
cluster8
# Out:
#   PostalCode Province   search  Latitude   Longitude 1st Most Common Venue  \
# 0        V9M       BC  V9M, BC  49.70103 -124.919617        Shop & Service
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Zoo    Falafel Restaurant     Electronics Store
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0  Ethiopian Restaurant           Event Space               Exhibit
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0           Fabric Shop                  Fair                   Farm

# %%
#cluster9
cluster9 = pd.read_csv("cluster9.csv")
cluster9
# Out:
#   PostalCode Province   search   Latitude   Longitude 1st Most Common Venue  \
# 0        V3W       BC  V3W, BC  49.146665 -122.856807           Bus Station
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Zoo    Falafel Restaurant     Electronics Store
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0  Ethiopian Restaurant           Event Space               Exhibit
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0           Fabric Shop                  Fair                   Farm

# %%
#cluster10
cluster10 = pd.read_csv("cluster10.csv")
cluster10
# Out:
#   PostalCode Province   search   Latitude   Longitude  \
# 0        M5P       ON  M5P, ON  43.696948  -79.411307
# 1        M4T       ON  M4T, ON  43.689574  -79.383160
# 2        V4E       BC  V4E, BC  49.117583 -122.903473
# 3        V4P       BC  V4P, BC  49.056842 -122.819221
# 4        V4R       BC  V4R, BC  49.240585 -122.561155
# 5        V6G       BC  V6G, BC  49.304260 -123.143792
# 6        V6S       BC  V6S, BC  49.253306 -123.222192
# 7        V7C       BC  V7C, BC  49.158647 -123.172266
# 8        V8X       BC  V8X, BC  48.478664 -123.362262
#
#         1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0               Jewelry Store      Sushi Restaurant                 Trail
# 1                  Restaurant                  Park                 Trail
# 2                       Trail                   Zoo             Drugstore
# 3  Construction & Landscaping                  Park                 Trail
# 4                        Lake                 Trail             Drugstore
# 5                       Trail                  Park                  Lake
# 6                       Trail                   Zoo             Drugstore
# 7                    Bus Stop      Sushi Restaurant                 Trail
# 8  Construction & Landscaping                  Park                 Trail
#
#          4th Most Common Venue        5th Most Common Venue  \
# 0                         Park                          Zoo
# 1                          Zoo  Eastern European Restaurant
# 2            Electronics Store         Ethiopian Restaurant
# 3                          Zoo                         Fair
# 4  Eastern European Restaurant            Electronics Store
# 5                         Fair  Eastern European Restaurant
# 6            Electronics Store         Ethiopian Restaurant
# 7                          Zoo           Falafel Restaurant
# 8                          Zoo                         Fair
#
#          6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                         Fair     Electronics Store  Ethiopian Restaurant
# 1            Electronics Store  Ethiopian Restaurant           Event Space
# 2                  Event Space               Exhibit           Fabric Shop
# 3  Eastern European Restaurant     Electronics Store  Ethiopian Restaurant
# 4         Ethiopian Restaurant           Event Space               Exhibit
# 5            Electronics Store  Ethiopian Restaurant           Event Space
# 6                  Event Space               Exhibit           Fabric Shop
# 7         Ethiopian Restaurant           Event Space               Exhibit
# 8  Eastern European Restaurant     Electronics Store  Ethiopian Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0           Event Space                Exhibit
# 1               Exhibit            Fabric Shop
# 2                  Fair     Falafel Restaurant
# 3           Event Space                Exhibit
# 4           Fabric Shop                   Fair
# 5               Exhibit            Fabric Shop
# 6                  Fair     Falafel Restaurant
# 7           Fabric Shop                   Fair
# 8           Event Space                Exhibit

# %% [markdown]
# ## V. Discussion and Conclusion

# %% [markdown]
# The goal of this project has value. Nevertheless, the results of the investigation showed that more refinement can be made as the choice for clusters. Known clusters could have been implemented to construct training and testing sets for the K-means clustering algorithm.
#
# Having said that there were interesting clusters of Ethiopian restaurants and Trails were found to have commonality. At the same time, another clustering algorithm could have been used alongside as a point of comparison (i.e. hierarchical clustering).
